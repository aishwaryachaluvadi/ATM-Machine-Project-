# %% [markdown]
# # ATM Machine Project Code
# Balance amount = 10000
# Chances = 3
# Pin: 1234
#
# Options (what options you like to choose)
# If pin wrong  - print you entered your incorrect
# If pin right – print you entered your pin correctly
# Press 1 – for your balance
# Press 2 to withdraw [50,100,200,500]
# If withdraw:  money should be deducted from balance amount and need to display
# Press 3 to pay in
# If pay in -  money should be added in balance amount
# Press 4 to return card
# Restart (would you like to go back) or else thank you)

# %%
balance_amount =10000
chances =3
pin=1234
chance=0



while chance<chances:
        a=int(input(("enter pin here:")))
        if a!=pin:
            print("Incorrect pin")
            chance=chance+1
        elif a==pin:
            print('''Press 1 to check your balance
Press 2 to withdraw money- 50, 100, 200, 500
Press 3 to add money
Press 4 Restart''')
            press=int(input(">"))
            if press==1:
                      print(f'Balance amount is {balance_amount}')
            elif press==2:
                    withdraw=[50,100,200,500]
                    drawing=int(input('choose amount from 50,100,200,500:'))
                    balance_amount=balance_amount-drawing
                    print(f'Balance amount is :{balance_amount}')
            elif press==3:
                    add_amount=int(input("Amount to add :"))
                    balance_amount=balance_amount+add_amount
                    print(f' Amount after adding is:{balance_amount}')
            elif press==4:
                    restart_return=input("do you want to restart or return card? ")
                    status=restart_return.lower()
                    if status=="return":
                        print('Thank You')
                        break
                    elif status=="restart":
                            a=int(input(("enter pin here:")))
                            chance=0
                            if chance<=chances:
                                if a!=pin:
                                    print("Incorrect pin")
                                elif a==pin:
                                        print('''Press 1 to check your balance
Press 2 to withdraw money- 50, 100, 200, 500
Press 3 to add money
Press 4 Restart''')
                                        press=int(input(">"))
                                        if press==1:
                                            print(f'Balance amount is {balance_amount}')
                                        elif press==2:
                                            withdraw=[50,100,200,500]
                                            drawing=int(input('choose amount from 50,100,200,500:'))
                                            balance_amount=balance_amount-drawing
                                            print(f'Balance amount is :{balance_amount}')
                                        elif press==3:
                                            add_amount=int(input("Amount to add :"))
                                            balance_amount=balance_amount+add_amount
                                            print(f' Amount after adding is:{balance_amount}')
            
                                        elif press==4:
                                           restart_return=input("do you want to restart or return card? ")
                                           status=restart_return.lower()
                                           if status=="return":
                                                 print('Thank You')
                                                 break
                
            else:
                print("I don't understand")
                break
# Out:
# enter pin here:1234
# Press 1 to check your balance
# Press 2 to withdraw money- 50, 100, 200, 500
# Press 3 to add money
# Press 4 Restart
# >1
# Balance amount is 10000
# enter pin here:1234
# Press 1 to check your balance
# Press 2 to withdraw money- 50, 100, 200, 500
# Press 3 to add money
# Press 4 Restart
# >2
# choose amount from 50,100,200,500:500
# Balance amount is :9500
# enter pin here:1234
# Press 1 to check your balance
# Press 2 to withdraw money- 50, 100, 200, 500
# Press 3 to add money
# Press 4 Restart
# >3
# Amount to add :1000
#  Amount after adding is:10500
# enter pin here:1234
# Press 1 to check your balance
# Press 2 to withdraw money- 50, 100, 200, 500
# Press 3 to add money
# Press 4 Restart
# >4
# do you want to restart or return card? restart
# enter pin here:2341
# Incorrect pin
# enter pin here:2345
# Incorrect pin
# enter pin here:2365
# Incorrect pin
# enter pin here:6785
# Incorrect pin
